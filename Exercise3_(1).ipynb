# %% [markdown]
# <a href="https://colab.research.google.com/github/Mallowsss/CCDATSCL_EXERCISES/blob/main/Exercise3_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 3
#
# <img src="https://img.itch.zone/aW1nLzM0MzUxOTUuanBn/original/FuMxog.jpg" />
#
# In this exercise, you will perform EDA on the popular Pokémon dataset, which contains detailed information about hundreds of Pokémon, including their stats, types, generation, and whether they are legendary.
#
# The Pokémon dataset is ideal for practicing EDA because it includes a mix of numerical features (such as Attack, Defense, Speed, HP) and categorical features (such as Type 1, Type 2, and Generation). This combination allows you to apply a wide range of EDA techniques, including summary statistics, data visualizations, grouping and aggregation, correlation analysis, and comparisons across categories.
#
# Throughout the exercise, you will explore questions such as:
# - Which Pokémon tend to have the highest or lowest stats?
# - How do different Pokémon types compare in terms of strength or defense?
# - Do Legendary Pokémon differ significantly from non-Legendary ones?
# - How are various stats distributed across the entire dataset?
# - Are there relationships or trade-offs between certain attributes (e.g., Attack vs. Defense)?

# %%
import kagglehub
import os
import pandas as pd

# %%
# Download latest version
path = kagglehub.dataset_download("abcsds/pokemon")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'pokemon' dataset.
# Path to dataset files: /kaggle/input/pokemon

# %%
if os.path.isdir(path):
  print(True)

contents = os.listdir(path)
contents

mydataset = path + "/" + contents[0]
mydataset


df = pd.read_csv(mydataset)
# Out:
# True

# %% [markdown]
# ## 1: Data Understanding (4 pts)

# %% [markdown]
# 1. Display the first 10 rows.

# %%
# put your answer here
df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# 2. Show dataset shape.

# %%
# put your answer here
df.shape
# Out:
# (800, 13)

# %% [markdown]
# 3. Show all columns and its data types.

# %%
# put your answer here
df.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# Total          int64
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %% [markdown]
# 4. Identify which columns contain missing values.

# %%
# put your answer here
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %% [markdown]
# ## 2. Summary Statistics (4 pts)

# %% [markdown]
# 1. Generate `df.describe()`.

# %%
# put your answer here
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# 50%     70.000000   65.000000     3.00000
# 75%     90.000000   90.000000     5.00000
# max    230.000000  180.000000     6.00000

# %% [markdown]
# 2. Get mean, median, and mode of Attack.

# %%
# put your answer here
print(f"Attack's Mean: {df.Attack.mean()}")
print(f"Attack's Median: {df.Attack.median()}")
print(f"Attack's Mode: {df.Attack.mode()}")
# Out:
# Attack's Mean: 79.00125
# Attack's Median: 75.0
# Attack's Mode: 0    100
# Name: Attack, dtype: int64

# %% [markdown]
# 3. Compute 25th and 75th percentiles for HP.

# %%
# put your answer here
print(f"HP's 25th Percentile: {df.HP.quantile(0.25)}")
print(f"HP's 75th Percentile: {df.HP.quantile(0.75)}")
# Out:
# HP's 25th Percentile: 50.0
# HP's 75th Percentile: 80.0

# %% [markdown]
# 4. Compute standard deviation and variance of Speed.

# %%
# put your answer here
print(f"Speed's Standard Deviation: {df.Speed.std()}")
print(f"Speed's Variance: {df.Speed.var()}")
# Out:
# Speed's Standard Deviation: 29.06047371716149
# Speed's Variance: 844.5111326658338

# %% [markdown]
# ## 3. Filtering & Selection `(7 pts)`

# %% [markdown]
# Select all Pokémon with Attack > 100.

# %%
# put your answer here
df[df.Attack > 100]
# Out:
#        #                       Name   Type 1  Type 2  Total   HP  Attack  \
# 7      6  CharizardMega Charizard X     Fire  Dragon    634   78     130
# 8      6  CharizardMega Charizard Y     Fire  Flying    634   78     104
# 12     9    BlastoiseMega Blastoise    Water     NaN    630   79     103
# 19    15      BeedrillMega Beedrill      Bug  Poison    495   65     150
# 39    34                   Nidoking   Poison  Ground    505   81     102
# ..   ...                        ...      ...     ...    ...  ...     ...
# 793  717                    Yveltal     Dark  Flying    680  126     131
# 796  719        DiancieMega Diancie     Rock   Fairy    700   50     160
# 797  720        HoopaHoopa Confined  Psychic   Ghost    600   80     110
# 798  720         HoopaHoopa Unbound  Psychic    Dark    680   80     160
# 799  721                  Volcanion     Fire   Water    600   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 7        111      130       85    100           1      False
# 8         78      159      115    100           1      False
# 12       120      135      115     78           1      False
# 19        40       15       80    145           1      False
# 39        77       85       75     85           1      False
# ..       ...      ...      ...    ...         ...        ...
# 793       95      131       98     99           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True
#
# [170 rows x 13 columns]

# %% [markdown]
# Select all Pokémon whose primary type (Type 1) is "Fire".

# %%
# put your answer here
df.loc[df["Type 1"] == "Fire", ["Name", "Type 1"]]
# Out:
#                           Name Type 1
# 4                   Charmander   Fire
# 5                   Charmeleon   Fire
# 6                    Charizard   Fire
# 7    CharizardMega Charizard X   Fire
# 8    CharizardMega Charizard Y   Fire
# 42                      Vulpix   Fire
# 43                   Ninetales   Fire
# 63                   Growlithe   Fire
# 64                    Arcanine   Fire
# 83                      Ponyta   Fire
# 84                    Rapidash   Fire
# 135                     Magmar   Fire
# 147                    Flareon   Fire
# 158                    Moltres   Fire
# 169                  Cyndaquil   Fire
# 170                    Quilava   Fire
# 171                 Typhlosion   Fire
# 236                     Slugma   Fire
# 237                   Magcargo   Fire
# 259                      Magby   Fire
# 263                      Entei   Fire
# 270                      Ho-oh   Fire
# 276                    Torchic   Fire
# 277                  Combusken   Fire
# 278                   Blaziken   Fire
# 279      BlazikenMega Blaziken   Fire
# 352                      Numel   Fire
# 353                   Camerupt   Fire
# 354      CameruptMega Camerupt   Fire
# 355                    Torkoal   Fire
# 435                   Chimchar   Fire
# 436                   Monferno   Fire
# 437                  Infernape   Fire
# 518                  Magmortar   Fire
# 542                    Heatran   Fire
# 557                      Tepig   Fire
# 558                    Pignite   Fire
# 559                     Emboar   Fire
# 572                    Pansear   Fire
# 573                   Simisear   Fire
# 614                   Darumaka   Fire
# 615    DarmanitanStandard Mode   Fire
# 616         DarmanitanZen Mode   Fire
# 692                    Heatmor   Fire
# 721                   Fennekin   Fire
# 722                    Braixen   Fire
# 723                    Delphox   Fire
# 730                Fletchinder   Fire
# 731                 Talonflame   Fire
# 735                     Litleo   Fire
# 736                     Pyroar   Fire
# 799                  Volcanion   Fire

# %% [markdown]
# Select all Pokémon that are Legendary.

# %%
# put your answer here
df.loc[df["Legendary"] == True, ["Name", "Legendary"]]
# Out:
#                     Name  Legendary
# 156             Articuno       True
# 157               Zapdos       True
# 158              Moltres       True
# 162               Mewtwo       True
# 163  MewtwoMega Mewtwo X       True
# ..                   ...        ...
# 795              Diancie       True
# 796  DiancieMega Diancie       True
# 797  HoopaHoopa Confined       True
# 798   HoopaHoopa Unbound       True
# 799            Volcanion       True
#
# [65 rows x 2 columns]

# %% [markdown]
# Select all Pokémon that are Generation 1 AND Legendary.

# %%
# put your answer here
df.loc[(df["Generation"] == 1) & (df["Legendary"] == True), ["Name", "Generation", "Legendary"]]
# Out:
#                     Name  Generation  Legendary
# 156             Articuno           1       True
# 157               Zapdos           1       True
# 158              Moltres           1       True
# 162               Mewtwo           1       True
# 163  MewtwoMega Mewtwo X           1       True
# 164  MewtwoMega Mewtwo Y           1       True

# %% [markdown]
# Select all Pokémon that are Water type OR Grass type.

# %%
# put your answer here
df.loc[(df["Type 1"] == "Water") | (df["Type 1"] == "Grass") & (df["Type 2"] == "Water") | (df["Type 2"] == "Grass"), ["Name", "Type 1", "Type 2"]]
# Out:
#                         Name Type 1 Type 2
# 9                   Squirtle  Water    NaN
# 10                 Wartortle  Water    NaN
# 11                 Blastoise  Water    NaN
# 12   BlastoiseMega Blastoise  Water    NaN
# 51                     Paras    Bug  Grass
# ..                       ...    ...    ...
# 783      PumpkabooSuper Size  Ghost  Grass
# 784    GourgeistAverage Size  Ghost  Grass
# 785      GourgeistSmall Size  Ghost  Grass
# 786      GourgeistLarge Size  Ghost  Grass
# 787      GourgeistSuper Size  Ghost  Grass
#
# [134 rows x 3 columns]

# %% [markdown]
# Select all Pokémon that are Fire type AND Attack > 120.

# %%
# put your answer here
df.loc[(df["Type 1"] == "Fire") & (df["Attack"] > 120) | (df["Type 2"] == "Fire") & (df["Attack"] > 120), ["Name", "Type 1", "Type 2", "Attack"]]
# Out:
#                           Name  Type 1    Type 2  Attack
# 7    CharizardMega Charizard X    Fire    Dragon     130
# 147                    Flareon    Fire       NaN     130
# 270                      Ho-oh    Fire    Flying     130
# 279      BlazikenMega Blaziken    Fire  Fighting     160
# 424      GroudonPrimal Groudon  Ground      Fire     180
# 559                     Emboar    Fire  Fighting     123
# 615    DarmanitanStandard Mode    Fire       NaN     140

# %% [markdown]
# Select all Pokémon whose type is in this list:
# `["Dragon", "Ghost", "Dark"]`.

# %%
# put your answer here
pokemon_types = ["Dragon", "Ghost", "Dark"]
df.loc[(df["Type 1"].isin(pokemon_types)) | (df["Type 2"].isin(pokemon_types)), ["Name", "Type 1", "Type 2"]]
# Out:
#                           Name   Type 1  Type 2
# 7    CharizardMega Charizard X     Fire  Dragon
# 99                      Gastly    Ghost  Poison
# 100                    Haunter    Ghost  Poison
# 101                     Gengar    Ghost  Poison
# 102          GengarMega Gengar    Ghost  Poison
# ..                         ...      ...     ...
# 791                    Noivern   Flying  Dragon
# 793                    Yveltal     Dark  Flying
# 794           Zygarde50% Forme   Dragon  Ground
# 797        HoopaHoopa Confined  Psychic   Ghost
# 798         HoopaHoopa Unbound  Psychic    Dark
#
# [139 rows x 3 columns]

# %% [markdown]
# ## 4. Categorical Exploration `(9 pts)`

# %% [markdown]
# Find the number of Pokémon per primary type.

# %%
# put your answer here
df["Type 1"].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# Find the number of Pokémon per generation.

# %%
# put your answer here
df["Generation"].value_counts()
# Out:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %% [markdown]
# Which type appears the most? Which appears the least?

# %%
# put your answer here
print(f"type that appears the most: {df["Type 1"].value_counts().idxmax()}")
print(f"type that apeears the least: {df["Type 1"].value_counts().idxmin()}")
# Out:
# type that appears the most: Water
# type that apeears the least: Flying

# %% [markdown]
# How many unique primary types (Type 1) exist?

# %%
# put your answer here
df["Type 1"].nunique()
# Out:
# 18

# %% [markdown]
# How many unique secondary types (Type 2) exist?

# %%
# put your answer here
df["Type 2"].nunique()
# Out:
# 18

# %% [markdown]
# Which primary types have the most dual-type combinations?

# %%
# put your answer here  --checking dual types
df_dual_type = df[df['Type 2'].notnull()]
df_dual_type.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 6  6              Charizard   Fire  Flying    534  78      84       78
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 6      109       85    100           1      False

# %%
# checking value counts for each type in primary
df_dual_type['Type 1'].value_counts()
# Out:
# Type 1
# Water       53
# Bug         52
# Normal      37
# Grass       37
# Rock        35
# Fire        24
# Ghost       22
# Steel       22
# Dragon      21
# Dark        21
# Ground      19
# Psychic     19
# Electric    17
# Poison      13
# Ice         11
# Fighting     7
# Fairy        2
# Flying       2
# Name: count, dtype: int64

# %%
# answer
most_dual_type_primary_type = unique_dual_type_counts.idxmax()
print(f"The primary type with the most dual-type combination is: {most_dual_type_primary_type}")
# Out:
# The primary type with the most dual-type combination is: Water

# %% [markdown]
# Which type has the highest mean Attack?

# %%
# put your answer here
df.groupby("Type 1")["Attack"].mean().idxmax()
# Out:
# 'Dragon'

# %% [markdown]
# Which type has the lowest mean Defense?

# %%
# put your answer here
df.groupby("Type 1")["Defense"].mean().idxmin()
# Out:
# 'Normal'

# %% [markdown]
# Which generation has the highest average Speed?

# %%
# put your answer here
print(f"Generation with the highest average Speed: {df.groupby('Generation')['Speed'].mean().idxmax()}")
# Out:
# Generation with the highest average Speed: 1

# %% [markdown]
# ## 5. Groupby & Aggregation `(13 pts)`

# %% [markdown]
# Compute the average Attack per primary type.

# %%
# put your answer here
df.groupby("Type 1")["Attack"].mean()
# Out:
# Type 1
# Bug          70.971014
# Dark         88.387097
# Dragon      112.125000
# Electric     69.090909
# Fairy        61.529412
# Fighting     96.777778
# Fire         84.769231
# Flying       78.750000
# Ghost        73.781250
# Grass        73.214286
# Ground       95.750000
# Ice          72.750000
# Normal       73.469388
# Poison       74.678571
# Psychic      71.456140
# Rock         92.863636
# Steel        92.703704
# Water        74.151786
# Name: Attack, dtype: float64

# %% [markdown]
# Compute the maximum HP per generation.

# %%
# put your answer here
df.groupby("Generation")["HP"].max()
# Out:
# Generation
# 1    250
# 2    255
# 3    170
# 4    150
# 5    165
# 6    126
# Name: HP, dtype: int64

# %% [markdown]
# Compute the total number of Pokémon per primary type.

# %%
# put your answer here
df["Type 1"].value_counts()
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %% [markdown]
# For each type, compute:
#
# - mean Attack
#
# - mean Defense
#
# - mean Speed

# %%
# put your answer here
print("Mean stats grouped by Type 1:")
print(df.groupby("Type 1")[["Attack", "Defense", "Speed"]].mean())
print("\nMean stats grouped by Type 2:")
print(df.groupby("Type 2")[["Attack", "Defense", "Speed"]].mean())
# Out:
# Mean stats grouped by Type 1:
#               Attack     Defense       Speed
# Type 1
# Bug        70.971014   70.724638   61.681159
# Dark       88.387097   70.225806   76.161290
# Dragon    112.125000   86.375000   83.031250
# Electric   69.090909   66.295455   84.500000
# Fairy      61.529412   65.705882   48.588235
# Fighting   96.777778   65.925926   66.074074
# Fire       84.769231   67.769231   74.442308
# Flying     78.750000   66.250000  102.500000
# Ghost      73.781250   81.187500   64.343750
# Grass      73.214286   70.800000   61.928571
# Ground     95.750000   84.843750   63.906250
# Ice        72.750000   71.416667   63.458333
# Normal     73.469388   59.846939   71.551020
# Poison     74.678571   68.821429   63.571429
# Psychic    71.456140   67.684211   81.491228
# Rock       92.863636  100.795455   55.909091
# Steel      92.703704  126.370370   55.259259
# Water      74.151786   72.946429   65.964286
#
# Mean stats grouped by Type 2:
#               Attack     Defense      Speed
# Type 2
# Bug        90.000000   80.000000  61.666667
# Dark      109.800000   72.050000  75.350000
# Dragon     94.444444   87.055556  80.555556
# Electric   72.666667   68.333333  71.500000
# Fairy      61.608696   73.869565  61.217391
# Fighting  112.846154   82.500000  87.384615
# Fire       81.250000   80.166667  79.666667
# Flying     80.288660   68.309278  85.721649
# Ghost      84.142857   82.285714  53.857143
# Grass      74.160000   80.120000  57.320000
# Ground     89.857143   90.314286  54.657143
# Ice        98.000000   85.642857  74.642857
# Normal     52.750000   53.750000  89.250000
# Poison     67.588235   59.558824  66.647059
# Psychic    74.696970   87.030303  69.484848
# Rock       84.000000  126.857143  36.000000
# Steel      92.590909  104.636364  59.363636
# Water      70.142857   85.071429  57.142857

# %% [markdown]
# For each generation, compute:
#
# - count
#
# - mean Total
#
# - number of Legendary Pokémon (hint: use sum on Boolean)

# %%
# put your answer here
df.groupby("Generation").agg(
    Count=('Name', 'count'),
    Total_Mean=('Total', 'mean'),
    Legendary_Count=('Legendary', 'sum')
)
# Out:
#             Count  Total_Mean  Legendary_Count
# Generation
# 1             166  426.813253                6
# 2             106  418.283019                5
# 3             160  436.225000               18
# 4             121  459.016529               13
# 5             165  434.987879               15
# 6              82  436.378049                8

# %% [markdown]
# Which type combination (Type 1 + Type 2) has the highest average Attack?

# %%
# put your answer here
df.groupby(["Type 1", "Type 2"])["Attack"].mean().idxmax()
# Out:
# ('Ground', 'Fire')

# %% [markdown]
# Which generation has the highest proportion of Legendary Pokémon?

# %%
# put your answer here
print(f"Generation with the highest Legendary Pokemon proportion: {df.groupby("Generation")["Legendary"].mean().idxmax()}")
# Out:
# Generation with the highest Legendary Pokemon proportion: 3

# %% [markdown]
# Which primary type has the largest variance in HP?

# %%
# put your answer here
df.groupby("Type 1")["HP"].var().idxmax()
# Out:
# 'Normal'

# %% [markdown]
# Which primary type has the highest median Speed?

# %%
# put your answer here
df.groupby("Type 1")["Speed"].median().idxmax()
# Out:
# 'Flying'

# %% [markdown]
# Group Pokémon by whether they are Legendary or not. Compare:
#
# - mean Total
#
# - mean Attack
#
# - mean Defense
#
# - mean Speed

# %%
# put your answer here
df.groupby("Legendary")[["Total", "Attack", "Defense", "Speed"]].mean()
# Out:
#                 Total      Attack    Defense       Speed
# Legendary
# False      417.213605   75.669388  71.559184   65.455782
# True       637.384615  116.676923  99.661538  100.184615

# %% [markdown]
# Show the top 5 strongest types by mean Total.

# %%
# put your answer here
df.groupby("Type 1")["Total"].mean().nlargest(5)
# Out:
# Type 1
# Dragon     550.531250
# Steel      487.703704
# Flying     485.000000
# Psychic    475.947368
# Fire       458.076923
# Name: Total, dtype: float64

# %% [markdown]
# Rank generations by their average Attack.

# %%
# put your answer here
df.groupby("Generation")["Attack"].mean().rank(ascending=False)
# Out:
# Generation
# 1    4.0
# 2    6.0
# 3    3.0
# 4    1.0
# 5    2.0
# 6    5.0
# Name: Attack, dtype: float64

# %% [markdown]
# Show the top 10 fastest Pokémon using nlargest(10, "Speed").

# %%
# put your answer here
df.nlargest(10, "Speed")
# Out:
#        #                       Name    Type 1  Type 2  Total  HP  Attack  \
# 431  386          DeoxysSpeed Forme   Psychic     NaN    600  50      95
# 315  291                    Ninjask       Bug  Flying    456  61      90
# 71    65      AlakazamMega Alakazam   Psychic     NaN    590  55      50
# 154  142  AerodactylMega Aerodactyl      Rock  Flying    615  80     135
# 428  386         DeoxysNormal Forme   Psychic     NaN    600  50     150
# 429  386         DeoxysAttack Forme   Psychic     NaN    600  50     180
# 19    15      BeedrillMega Beedrill       Bug  Poison    495  65     150
# 275  254      SceptileMega Sceptile     Grass  Dragon    630  70     110
# 678  617                   Accelgor       Bug     NaN    495  80      70
# 109  101                  Electrode  Electric     NaN    480  60      50
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 431       90       95       90    180           3       True
# 315       45       50       50    160           3      False
# 71        65      175       95    150           1      False
# 154       85       70       95    150           1      False
# 428       50      150       50    150           3       True
# 429       20      180       20    150           3       True
# 19        40       15       80    145           1      False
# 275       75      145       85    145           3      False
# 678       40      100       60    145           5      False
# 109       70       80       80    140           1      False
